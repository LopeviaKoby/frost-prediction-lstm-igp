# %% [markdown]
# # Preprocessing v01: Limpieza y Definicion del Target
#
# En esta etapa se aplican reglas simples de control de calidad y se construye el dataset procesado para modelado.

# %% [markdown]
# ## Principios de esta etapa
#
# - no inventar datos;
# - no imputar con informacion futura;
# - no mezclar limpieza con optimizacion;
# - dejar trazabilidad clara de las reglas aplicadas.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT.name != 'frost_ema_igp' and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT

# %%
from src.data.loaders import load_raw_hourly_dataset
from src.features.preprocessing import apply_physical_constraints, build_processed_dataset

raw_df = load_raw_hourly_dataset()
clean_df, quality_report = apply_physical_constraints(raw_df)
processed_df = build_processed_dataset(clean_df)

quality_report.head(20)

# %%
processed_df[[
    'tempsup_min',
    'HR_mean',
    'radinf_mean',
    'frost_event_current',
    'frost_event_t_plus_12h',
    'target_timestamp',
]].head()

# %%
processed_df[['frost_event_current', 'frost_event_t_plus_12h']].mean().rename('positive_rate')

# %% [markdown]
# ## Resultado esperado
#
# Al terminar este notebook ya deberiamos tener claro que el target del baseline es de pronostico y no de clasificacion contemporanea.
