# %% [markdown]
# # Contexto del Proyecto y Literatura Base
#
# Este notebook organiza el contexto tecnico del proyecto, deja por escrito la pregunta de modelado baseline y resume la bibliografia que guia las primeras decisiones metodologicas.

# %% [markdown]
# ## Objetivo de esta etapa
#
# En esta version no buscamos el mejor modelo posible. Buscamos recuperar el proyecto con disciplina ingenieril y llegar a una primera linea base LSTM que sea:
#
# - reproducible;
# - comprensible;
# - segura para una laptop de estudiante;
# - metodologicamente defendible.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT.name != 'frost_ema_igp' and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT

# %%
from pathlib import Path

for path in [
    PROJECT_ROOT / 'docs' / 'recovery_plan.md',
    PROJECT_ROOT / 'docs' / 'methodology.md',
    PROJECT_ROOT / 'docs' / 'laptop_training_requirements.md',
    PROJECT_ROOT / 'reports' / 'paper_notes' / 'literature_synthesis_v01.md',
]:
    print(f'
===== {path.name} =====
')
    print(path.read_text(encoding='utf-8')[:4000])

# %% [markdown]
# ## Pregunta baseline de modelado
#
# Formulacion adoptada en `v01`:
#
# > Usando las ultimas 24 horas de observaciones meteorologicas horarias, estimar si se producira una helada 12 horas despues.
#
# Esto define una tarea de clasificacion binaria con foco en utilidad practica, simplicidad y control del riesgo de fuga de informacion.

# %% [markdown]
# ## Nota metodologica importante
#
# La literatura revisada deja claro que las heladas y los eventos frios en Mantaro tienen componentes locales y de gran escala. En consecuencia, este baseline debe interpretarse como un modelo local de series temporales, no como una explicacion fisica completa del fenomeno.
