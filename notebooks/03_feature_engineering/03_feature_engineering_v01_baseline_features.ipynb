# %% [markdown]
# # Feature Engineering v01
#
# Este notebook revisa las variables que entraran al baseline y por que fueron retenidas.

# %% [markdown]
# ## Criterio general
#
# Como primera version, se prefieren variables observadas y transformaciones temporales simples. Se evita una explosion de features derivadas hasta validar primero la consistencia del pipeline.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT.name != 'frost_ema_igp' and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT

# %%
from src.data.loaders import load_raw_hourly_dataset
from src.features.preprocessing import apply_physical_constraints, build_processed_dataset, select_feature_columns

raw_df = load_raw_hourly_dataset()
clean_df, _ = apply_physical_constraints(raw_df)
processed_df = build_processed_dataset(clean_df)
feature_columns = select_feature_columns(processed_df.columns)

len(feature_columns), feature_columns[:15]

# %%
processed_df[feature_columns].describe().T.head(20)

# %% [markdown]
# ## Comentario tecnico
#
# En una fase posterior se podrian incorporar proxies mas refinados o variables exogenas. En `v01` se prioriza que cada feature sea justificable, interpretable y computacionalmente manejable.
