# %% [markdown]
# # Evaluacion v01 de la LSTM Baseline
#
# Este notebook carga las metricas y predicciones generadas por el entrenamiento baseline y organiza la lectura tecnica de resultados.

# %% [markdown]
# ## Preguntas de evaluacion
#
# - El modelo supera una referencia ingenua razonable.
# - El recall es suficiente para considerar una siguiente iteracion.
# - Los errores observados apuntan a problemas de calidad de dato, de definicion del target o de capacidad del modelo.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT.name != 'frost_ema_igp' and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT

# %%
import json
import pandas as pd

metrics_path = PROJECT_ROOT / 'outputs' / 'metrics' / 'lstm_baseline_v01_metrics.json'
predictions_path = PROJECT_ROOT / 'outputs' / 'predictions' / 'lstm_baseline_v01_predictions.csv'

if metrics_path.exists():
    metrics = json.loads(metrics_path.read_text(encoding='utf-8'))
    metrics
else:
    print('No se encontraron metricas guardadas.')

if predictions_path.exists():
    predictions_df = pd.read_csv(predictions_path, parse_dates=['origin_timestamp', 'target_timestamp'])
    predictions_df.head()
else:
    print('No se encontraron predicciones guardadas.')

# %%
from IPython.display import Image, display

for figure_name in [
    'lstm_baseline_v01_training_curve.png',
    'lstm_baseline_v01_confusion_matrix.png',
    'lstm_baseline_v01_roc_curve.png',
]:
    figure_path = PROJECT_ROOT / 'reports' / 'figures' / figure_name
    if figure_path.exists():
        display(Image(filename=str(figure_path)))

# %% [markdown]
# ## Cierre de etapa
#
# La siguiente iteracion deberia enfocarse primero en revisar errores y umbrales, y solo despues considerar busqueda de hiperparametros o variables externas.
