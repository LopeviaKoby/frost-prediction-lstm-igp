# %% [markdown]
# # LSTM Baseline Training v01
#
# Este notebook documenta el primer entrenamiento completo de la linea base LSTM.

# %% [markdown]
# ## Recordatorio metodologico
#
# - split cronologico
# - target desplazado a futuro
# - escalado ajustado solo con entrenamiento
# - sin tuning de hiperparametros
# - recall como metrica de interes practico

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT.name != 'frost_ema_igp' and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT

# %%
from src.models.train_lstm_baseline import main

# %%
# Ejecutar esta celda para lanzar el entrenamiento baseline completo.
main()

# %%
from pathlib import Path
import json

metrics_path = PROJECT_ROOT / 'outputs' / 'metrics' / 'lstm_baseline_v01_metrics.json'
if metrics_path.exists():
    metrics = json.loads(metrics_path.read_text(encoding='utf-8'))
    metrics
else:
    print('Aun no se han generado metricas. Ejecuta la celda de entrenamiento.')

# %% [markdown]
# ## Comentario final
#
# Si el entrenamiento corre de forma estable y deja artefactos versionados, el objetivo de esta etapa se considera cumplido incluso si el desempeno aun no es sobresaliente.
